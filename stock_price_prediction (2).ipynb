# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10
from keras.models import Sequential
from keras.layers import LSTM,Dropout,Dense
from sklearn.preprocessing import MinMaxScaler

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dca89113-dc04-466e-9698-3f6bfe933bd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dca89113-dc04-466e-9698-3f6bfe933bd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving training_data.csv to training_data.csv

# %%
data = pd.read_csv('training_data.csv')
data.head(10)
# Out:
#          Date    Open    High  ...   Close  Total Trade Quantity  Turnover (Lacs)
# 0  2018-10-08  208.00  222.25  ...  215.15             4642146.0         10062.83
# 1  2018-10-05  217.00  218.60  ...  209.20             3519515.0          7407.06
# 2  2018-10-04  223.50  227.80  ...  218.20             1728786.0          3815.79
# 3  2018-10-03  230.00  237.50  ...  227.60             1708590.0          3960.27
# 4  2018-10-01  234.55  234.60  ...  230.90             1534749.0          3486.05
# 5  2018-09-28  234.05  235.95  ...  233.75             3069914.0          7162.35
# 6  2018-09-27  234.55  236.80  ...  233.25             5082859.0         11859.95
# 7  2018-09-26  240.00  240.00  ...  234.25             2240909.0          5248.60
# 8  2018-09-25  233.30  236.75  ...  236.10             2349368.0          5503.90
# 9  2018-09-24  233.55  239.20  ...  233.30             3423509.0          7999.55
#
# [10 rows x 8 columns]

# %%
data.describe()
# Out:
#               Open         High  ...  Total Trade Quantity  Turnover (Lacs)
# count  1235.000000  1235.000000  ...          1.235000e+03      1235.000000
# mean    168.954858   171.429069  ...          2.604151e+06      4843.166502
# std      51.499145    52.436761  ...          2.277028e+06      5348.919832
# min     103.000000   104.600000  ...          1.001800e+05       128.040000
# 25%     137.550000   138.925000  ...          1.284482e+06      1801.035000
# 50%     151.500000   153.250000  ...          1.964885e+06      3068.510000
# 75%     169.000000   172.325000  ...          3.095788e+06      5852.600000
# max     327.700000   328.750000  ...          2.919102e+07     55755.080000
#
# [8 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   object
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   float64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 77.3+ KB

# %%
data.isna().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
data.duplicated().value_counts()
# Out:
# False    1235
# dtype: int64

# %%
data["Date"]=pd.to_datetime(data.Date,format="%Y-%m-%d")
data.index=data['Date']
plt.figure(figsize=(16,8))
plt.plot(data["Last"],label='Last Price history')

# %%
data["Date"]=pd.to_datetime(data.Date,format="%Y-%m-%d")
data.index=data['Date']
plt.figure(figsize=(16,8))
plt.plot(data["Turnover (Lacs)"],label='Turnover(Lacs) Price history')

# %%
data=data.sort_index(ascending=True,axis=0)
dataset=pd.DataFrame(index=range(0,len(data)),columns=['Date','Close'])
for i in range(0,len(data)):
    dataset["Date"][i]=data['Date'][i]
    dataset["Close"][i]=data["Close"][i]
dataset
# Out:
#                      Date   Close
# 0     2013-10-08 00:00:00   155.8
# 1     2013-10-09 00:00:00  155.55
# 2     2013-10-10 00:00:00  160.15
# 3     2013-10-11 00:00:00  160.05
# 4     2013-10-14 00:00:00  159.45
# ...                   ...     ...
# 1230  2018-10-01 00:00:00   230.9
# 1231  2018-10-03 00:00:00   227.6
# 1232  2018-10-04 00:00:00   218.2
# 1233  2018-10-05 00:00:00   209.2
# 1234  2018-10-08 00:00:00  215.15
#
# [1235 rows x 2 columns]

# %%
#dataset["Date"]=pd.to_datetime(dataset.Date,format="%Y-%m-%d")
dataset['Date'] = pd.to_numeric(pd.to_datetime(dataset['Date']))
dataset.index=dataset['Date']
plt.figure(figsize=(16,8))
plt.xlabel('Year')
plt.ylabel('Close Price')
plt.plot(dataset["Close"],label='Close Price history')

# %%
scaler=MinMaxScaler(feature_range=(0,1))
final_dataset=dataset.values
train_data=final_dataset[0:987,:]
valid_data=final_dataset[987:,:]
dataset.index=dataset.Date
dataset.drop("Date",axis=1,inplace=True)
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(final_dataset)
x_train_data,y_train_data=[],[]
for i in range(60,len(train_data)):
    x_train_data.append(scaled_data[i-60:i,0])
    y_train_data.append(scaled_data[i,0])
    
x_train_data,y_train_data=np.array(x_train_data),np.array(y_train_data)
x_train_data=np.reshape(x_train_data,(x_train_data.shape[0],x_train_data.shape[1],1))

# %%
x_train_data
# Out:
# (927, 60, 1)

# %%
lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_data.shape[1],1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))
inputs_data=dataset[len(dataset)-len(valid_data)-60:].values
#inputs_data=inputs_data.reshape(-1,1)
inputs_data=scaler.transform(inputs_data)
lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1,verbose=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-42ee9758adc2> in <module>()
#       5 inputs_data=dataset[len(dataset)-len(valid_data)-60:].values
#       6 #inputs_data=inputs_data.reshape(-1,1)
# ----> 7 inputs_data=scaler.transform(inputs_data)
#       8 lstm_model.compile(loss='mean_squared_error',optimizer='adam')
#       9 lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1,verbose=2)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in transform(self, X)
#     412                         force_all_finite="allow-nan")
#     413
# --> 414         X *= self.scale_
#     415         X += self.min_
#     416         return X
#
# ValueError: non-broadcastable output operand with shape (308,1) doesn't match the broadcast shape (308,2)
